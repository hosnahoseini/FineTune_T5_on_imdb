# %% [markdown]
# # Homework 1 Part 5
#
# ## Course Name: Large Language Models
# #### Lecturers: Dr. Soleimani, Dr. Rohban, Dr. Asgari
#
# ---
#
# #### Notebooks Supervised By: MohammadAli SadraeiJavaheri
# #### Notebooks Prepared By: Zeinab Sadat Taghavi, Hamed Jamshidian, Seyed Mohammad Reza Modarres
#
# **Contact**: Ask your questions in Quera
#
# ---
#
# ### Instructions:
# - Complete all exercises presented in this notebook.
# - Ensure you run each cell after you've entered your solution.
# - After completing the exercises, save the notebook and <font color='red'>follow the submission guidelines provided in the PDF.</font>
#
#
# ---
#
# **Note**: Replace the placeholders (between `## Your code begins ##` and `## Your code ends ##`) with the appropriate details.

# %% [markdown]
# # Introduction

# %% [markdown]
# ### What is LoRA?

# %% [markdown]
# Low-rank adaptation, or LoRA, is a finetuning method that was developed by [Hu et al. in 2021](https://https://arxiv.org/abs/2106.09685). It is based on the idea that most models are overparameterized. If most models are overparameterized, then modifying all of the model's parameters during finetuning is a waste of compute. We should be able to modify a small subset of parameters and still be able to achieve improved performance on the targeted objective. This is the key idea behind LoRa.
#
# This process involves injecting the matrices into the dense layer's update, optimizing them for the specific adaptation task while the original pretrained model weights remain unchanged.
#
# Here are some of the key points of the LoRA technique:
#
# * **Freezing Pretrained Weights**: Instead of modifying all the parameters of a pretrained model during fine-tuning, LoRA freezes the pretrained weights. This means that the original model weights remain unchanged during the adaptation process.
#
# * **Rank Decomposition Matrices**: LoRA freezes the pretrained model weights and injects trainable rank decomposition matrices into each layer of the Transformer architecture. These matrices are used to adjust the output of each layer in a way that's specific to the adaptation task.
#
# * **Indirect Training of Dense Layers**: The rank decomposition matrices allow for the indirect training of each dense layer in the neural network. They are injected into the layer's update during the adaptation process and optimized to enhance the layer's performance on the specific task or domain.
#
# * **Significant Reduction in Trainable Parameters**: By focusing on these rank decomposition matrices instead of the entire set of model weights, LoRA greatly reduces the number of trainable parameters for downstream tasks. For instance, in the case of GPT-3, LoRA can reduce the number of trainable parameters by a factor of 10,000.
#
# * **Maintaining Model Performance**: Despite the significant reduction in the number of trainable parameters, the LoRA technique is designed to maintain or even improve the performance of the large language model on the specific task or domain.
#
# ![pic.png](data:image/png;base64,...)
#
#
# In a nutshell, in LoRA you freeze all the models weights and then inject low rank matrices A, B into any linear layer that you want. if the inititall linear layer has n\*m dimensions, A dimension must be n\*r and B r\* m so A@B will have n\*m dmentions and can be added with W (the pretained weight).
#
# Now some details:
#
# When doing regular fine-tuning, we update W and get x.W as the output of the module but here we freeze W and update A and B and the output of the module is h = x.W + x.A@B. since W  and A@B have the same dimentions, the addition is possible.
#
# We also need to scale x.A@B by a scaling factor $α$.
#
# According to the paper, A should be initialized with [Kaiming He initialization](https://medium.com/@shauryagoel/kaiming-he-initialization-a8d9ed0b5899
# )
# and B initialized to zeros.
#
# Useful links:
# * [https://arxiv.org/abs/2106.09685](https://)
# * [https://huggingface.co/docs/peft/conceptual_guides/lora](https://)
# * [https://sh-tsang.medium.com/brief-review-lora-low-rank-adaptation-of-large-language-models-faf5ddd5802f](https://)

# %% [markdown]
# ### Requirements

# %%
# %%capture
! pip install datasets transformers

# %%
pip install torch==1.10
# Out:
# Collecting torch==1.10
#   Using cached torch-1.10.0-cp38-cp38-manylinux1_x86_64.whl (881.9 MB)
# Requirement already satisfied: typing-extensions in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch==1.10) (4.7.1)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0
#     Uninstalling torch-1.13.0:
#       Successfully uninstalled torch-1.13.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.6.1 requires torch>=1.13.0, but you have torch 1.10.0 which is incompatible.
# pytorch-lightning 2.0.4 requires torch>=1.11.0, but you have torch 1.10.0 which is incompatible.
# Successfully installed torch-1.10.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Imports

# %%
from tqdm.notebook import tqdm
from IPython import display

import numpy as np
import pandas as pd
import math

from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn

from datasets import load_dataset
from transformers import T5TokenizerFast, T5ForConditionalGeneration, DataCollatorForSeq2Seq

# %% [markdown]
# ### Constants

# %% [markdown]
# We will use `t5-small` as our base model. We want to tune `10` soft prompt tokens.

# %%
#####################################
###### DO NOT CHANGE THIS CELL ######
#####################################

BASE_MODEL_NAME = 't5-small'

BATCH_SIZE = 32
LEARNING_RATE = 1e-4
EPOCHS = 10
RANK = 8
ALPHA = 4.0

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Dataset

# %% [markdown]
# ### Load dataset

# %% [markdown]
# `imdb` dataset is a famouns NLP sentiment dataset. Each row of data is either `negative` or `positive`.

# %%
dataset = load_dataset('imdb')
dataset.pop('unsupervised')
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
# })

# %% [markdown]
# ### Define related functions

# %% [markdown]
# Because `T5` model is a sequence to sequence model we should map our labels to label_names before training and doing vice versa duing calculating metrics.
#
# The functions `id2label` and `label2id` are defined to do this.

# %%
def id2label(ids):
    label_names = ['negative', 'positive']
    return [label_names[id] for id in ids]

def label2id(labels):
    label_names_dict = {
        'negative': 0,
        'positive': 1
    }
    return [
        label_names_dict.get(label, 2)
        for label in labels
    ]

# %% [markdown]
# # Tokenizer

# %% [markdown]
# ### Load tokenizer

# %%
tokenizer = T5TokenizerFast.from_pretrained(BASE_MODEL_NAME)

# %% [markdown]
# ### Process dataset using tokenizer

# %% [markdown]
# In this step we will getting our dataset ready for training.
#
# We preprocess tokenize our `text` and `label`.

# %%
def preprocess_input(text):
    text = text.lower()
    text = text.replace('<br />', ' ')
    return text

def map_function(row):
    processed_input = [
        preprocess_input(text)
        for text in row['text']
    ]
    input_info = tokenizer(processed_input, truncation=True, max_length=256)
    output_info = tokenizer(id2label(row['label']))
    return {
        **input_info,
        'labels': output_info.input_ids
    }


dataset = dataset.map(map_function, batched=True)
dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

# %% [markdown]
# # Model

# %% [markdown]
# ### Load model

# %%
model = T5ForConditionalGeneration.from_pretrained(BASE_MODEL_NAME)

# %% [markdown]
# ### Implementing LoRA

# %% [markdown]
# Here we implement LoraLayer, the module which we want to replace with Linear modules.
#
# <font color='#73FF73'><b>You have to complete</b></font> `LoRALayer` <font color='#73FF73'><b>function.</b></font>
#
# Replace `None` with your code.
#
# Do not forget that linear layer in lora doesn't have `bias`.
#
# You can use `nn.init.kaiming_uniform_` and `nn.init.zeros_` for initilization.

# %%
import torch
import torch.nn as nn
import torch.nn.init as init

class LoRALayer(nn.Module):
    def __init__(
        self,
        module: nn.Linear,
        rank: int = RANK,
        alpha: float = ALPHA
    ):

        super().__init__()
        self.rank = rank
        self.alpha = alpha
        self.scaling = self.alpha / self.rank  # scaling factor
        self.in_dim = module.in_features
        self.out_dim = module.out_features
        self.pretrained = module

        ######### Your code begins #########
        # create the A and initialize with Kaiming
        self.sharif_llm_A = nn.Parameter(torch.Tensor(self.in_dim, self.rank))
        init.kaiming_uniform_(self.sharif_llm_A, a=math.sqrt(5))
        
        # create B and initialize with zeros
        self.sharif_llm_B = nn.Parameter(torch.zeros(self.rank, self.out_dim))
        ######### Your code ends ###########

    def forward(self, x: torch.Tensor):

        pretrained_out = self.pretrained(x)  # get the pretrained weights -> x.W

        # do the forward path for low rank matrices and scale the result
        ######### Your code begins #########
        lora_out = x @ self.sharif_llm_A
        lora_out = lora_out @ self.sharif_llm_B
        lora_out = lora_out * self.scaling
        ######### Your code ends ###########

        return pretrained_out + lora_out  # x@W + x@A@B*(scaling_factor)

# %% [markdown]
# ### Change the model

# %% [markdown]
# Now we want to change the model and replace some modlues with LoRA modules. The following picture from the original paper shows what we can change and what rank should we use.
# ![dfd.PNG](data:image/png;base64,...)
#
# Here we set RANK to be 4 and want to change query and value matrices but you can try other ranks and matrices for your self.

# %% [markdown]
# <font color='#73FF73'><b>You have to complete</b></font> `mutate_model` <font color='#73FF73'><b>function.</b></font>
#
# Replace `None` with your code.

# %%
def mutate_model(model: nn.Module, rank: int = RANK, alpha: float = ALPHA):
    """
    Replaces all linear layers in the model with LoRALinear layers.
    Freeze all params except LoRA params.
    """
    # make sure there are no LoRALayer is in the model; return if there are any
    for name, module in model.named_modules():
        if isinstance(module, LoRALayer):
            print("Model already contains LoRALinear layers! \n Try reloading the model.")
            return

    # we want to replace all query and value Linear modules with LoRALayer

    # iterate over the children of the model
    for name, module in model.named_children():
        # if the module is linear and the name is for query or value
        if isinstance(module, nn.Linear) and (name == 'q' or name == 'v'):
            # replace the module with LoRALayer
            ######### Your code begins #########
            lora_layer = LoRALayer(module, rank=rank, alpha=alpha)
            ######### Your code ends ###########
            setattr(model, name, lora_layer)
            print(f"Replaced {name} with LoRALinear layer.")
        else:
            mutate_model(module, rank, alpha) # recursively call the function on the module

mutate_model(model)
# Out:
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.
# Replaced q with LoRALinear layer.
# Replaced v with LoRALinear layer.

# %% [markdown]
# ### Freeze non LoRA params

# %%
def freeze_non_LoRA(model, peft_key):
    print('Non freezed weights:')
    for param_name, weights in model.named_parameters():
        weights.requires_grad = peft_key in param_name
        if weights.requires_grad:
            print(param_name)

freeze_non_LoRA(model, peft_key='sharif_llm')
# Out:
# Non freezed weights:
# encoder.block.0.layer.0.SelfAttention.q.sharif_llm_A
# encoder.block.0.layer.0.SelfAttention.q.sharif_llm_B
# encoder.block.0.layer.0.SelfAttention.v.sharif_llm_A
# encoder.block.0.layer.0.SelfAttention.v.sharif_llm_B
# encoder.block.1.layer.0.SelfAttention.q.sharif_llm_A
# encoder.block.1.layer.0.SelfAttention.q.sharif_llm_B
# encoder.block.1.layer.0.SelfAttention.v.sharif_llm_A
# encoder.block.1.layer.0.SelfAttention.v.sharif_llm_B
# encoder.block.2.layer.0.SelfAttention.q.sharif_llm_A
# encoder.block.2.layer.0.SelfAttention.q.sharif_llm_B
# encoder.block.2.layer.0.SelfAttention.v.sharif_llm_A
# encoder.block.2.layer.0.SelfAttention.v.sharif_llm_B
# encoder.block.3.layer.0.SelfAttention.q.sharif_llm_A
# encoder.block.3.layer.0.SelfAttention.q.sharif_llm_B
# encoder.block.3.layer.0.SelfAttention.v.sharif_llm_A
# encoder.block.3.layer.0.SelfAttention.v.sharif_llm_B
# encoder.block.4.layer.0.SelfAttention.q.sharif_llm_A
# encoder.block.4.layer.0.SelfAttention.q.sharif_llm_B
# encoder.block.4.layer.0.SelfAttention.v.sharif_llm_A
# encoder.block.4.layer.0.SelfAttention.v.sharif_llm_B
# encoder.block.5.layer.0.SelfAttention.q.sharif_llm_A
# encoder.block.5.layer.0.SelfAttention.q.sharif_llm_B
# encoder.block.5.layer.0.SelfAttention.v.sharif_llm_A
# encoder.block.5.layer.0.SelfAttention.v.sharif_llm_B
# decoder.block.0.layer.0.SelfAttention.q.sharif_llm_A
# decoder.block.0.layer.0.SelfAttention.q.sharif_llm_B
# decoder.block.0.layer.0.SelfAttention.v.sharif_llm_A
# decoder.block.0.layer.0.SelfAttention.v.sharif_llm_B
# decoder.block.0.layer.1.EncDecAttention.q.sharif_llm_A
# decoder.block.0.layer.1.EncDecAttention.q.sharif_llm_B
# decoder.block.0.layer.1.EncDecAttention.v.sharif_llm_A
# decoder.block.0.layer.1.EncDecAttention.v.sharif_llm_B
# decoder.block.1.layer.0.SelfAttention.q.sharif_llm_A
# decoder.block.1.layer.0.SelfAttention.q.sharif_llm_B
# decoder.block.1.layer.0.SelfAttention.v.sharif_llm_A
# decoder.block.1.layer.0.SelfAttention.v.sharif_llm_B
# decoder.block.1.layer.1.EncDecAttention.q.sharif_llm_A
# decoder.block.1.layer.1.EncDecAttention.q.sharif_llm_B
# decoder.block.1.layer.1.EncDecAttention.v.sharif_llm_A
# decoder.block.1.layer.1.EncDecAttention.v.sharif_llm_B
# decoder.block.2.layer.0.SelfAttention.q.sharif_llm_A
# decoder.block.2.layer.0.SelfAttention.q.sharif_llm_B
# decoder.block.2.layer.0.SelfAttention.v.sharif_llm_A
# decoder.block.2.layer.0.SelfAttention.v.sharif_llm_B
# decoder.block.2.layer.1.EncDecAttention.q.sharif_llm_A
# decoder.block.2.layer.1.EncDecAttention.q.sharif_llm_B
# decoder.block.2.layer.1.EncDecAttention.v.sharif_llm_A
# decoder.block.2.layer.1.EncDecAttention.v.sharif_llm_B
# decoder.block.3.layer.0.SelfAttention.q.sharif_llm_A
# decoder.block.3.layer.0.SelfAttention.q.sharif_llm_B
# decoder.block.3.layer.0.SelfAttention.v.sharif_llm_A
# decoder.block.3.layer.0.SelfAttention.v.sharif_llm_B
# decoder.block.3.layer.1.EncDecAttention.q.sharif_llm_A
# decoder.block.3.layer.1.EncDecAttention.q.sharif_llm_B
# decoder.block.3.layer.1.EncDecAttention.v.sharif_llm_A
# decoder.block.3.layer.1.EncDecAttention.v.sharif_llm_B
# decoder.block.4.layer.0.SelfAttention.q.sharif_llm_A
# decoder.block.4.layer.0.SelfAttention.q.sharif_llm_B
# decoder.block.4.layer.0.SelfAttention.v.sharif_llm_A
# decoder.block.4.layer.0.SelfAttention.v.sharif_llm_B
# decoder.block.4.layer.1.EncDecAttention.q.sharif_llm_A
# decoder.block.4.layer.1.EncDecAttention.q.sharif_llm_B
# decoder.block.4.layer.1.EncDecAttention.v.sharif_llm_A
# decoder.block.4.layer.1.EncDecAttention.v.sharif_llm_B
# decoder.block.5.layer.0.SelfAttention.q.sharif_llm_A
# decoder.block.5.layer.0.SelfAttention.q.sharif_llm_B
# decoder.block.5.layer.0.SelfAttention.v.sharif_llm_A
# decoder.block.5.layer.0.SelfAttention.v.sharif_llm_B
# decoder.block.5.layer.1.EncDecAttention.q.sharif_llm_A
# decoder.block.5.layer.1.EncDecAttention.q.sharif_llm_B
# decoder.block.5.layer.1.EncDecAttention.v.sharif_llm_A
# decoder.block.5.layer.1.EncDecAttention.v.sharif_llm_B

# %% [markdown]
# # Train and evaluate

# %% [markdown]
# ### Define dataloaders

# %%
col_fn = DataCollatorForSeq2Seq(
    tokenizer, return_tensors='pt', padding='longest',
)

train_loader = torch.utils.data.DataLoader(
    dataset['train'],
    batch_size=BATCH_SIZE,
    collate_fn=col_fn,
    shuffle=True
)

test_loader = torch.utils.data.DataLoader(
    dataset['test'],
    batch_size=BATCH_SIZE,
    collate_fn=col_fn,
    shuffle=True
)

# %% [markdown]
# ### Train functions

# %%
def train_loop(model, loader, optimizer):
    model.train()

    batch_losses = []

    for row in tqdm(loader, desc='Training:'):
        optimizer.zero_grad()

        out = model(**row.to(model.device))
        loss = out.loss

        batch_loss_value = loss.item()
        loss.backward()
        optimizer.step()

        batch_losses.append(batch_loss_value)

    loss_value = np.mean(batch_losses)
    return {'train_loss': loss_value}

def _predict(model, row):
    return model.generate(
        input_ids=row.input_ids,
        attention_mask=row.attention_mask,
        max_length=5
    )

def tokenizer_ids_to_label(all_input_ids):
    return tokenizer.batch_decode(all_input_ids, skip_special_tokens=True)

def valid_loop(model, loader, compute_metrics):
    model.eval()

    all_true = []
    all_pred = []

    with torch.no_grad():
        for row in tqdm(loader, desc='Validating:'):
            row.to(model.device)
            pred = _predict(model, row)

            all_true += row.labels.detach().cpu().tolist()
            all_pred += pred.detach().cpu().tolist()

    all_true = label2id(tokenizer_ids_to_label(all_true))
    all_pred = label2id(tokenizer_ids_to_label(all_pred))

    return {'valid_acc': compute_metrics(y_true=all_true, y_pred=all_pred)}

# %% [markdown]
# ### Define our optimizer and metric function

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
compute_metrics = accuracy_score

# %%
model.to(DEVICE)

all_results = []
for epoch in range(EPOCHS):
    epoch_results = {'epoch': epoch}

    epoch_results.update(
        train_loop(
            model=model,
            loader=train_loader,
            optimizer=optimizer,
        )
    )

    epoch_results.update(
        valid_loop(
            model=model,
            loader=test_loader,
            compute_metrics=compute_metrics,
        )
    )
    all_results.append(epoch_results)

    display.clear_output()
    display.display(pd.DataFrame(all_results).set_index('epoch'))
# Out:
#        train_loss  valid_acc
# epoch
# 0        2.510336    0.82844
# 1        0.209475    0.85452
# 2        0.183873    0.86668
# 3        0.172725    0.87304
# 4        0.163720    0.88012
# 5        0.157784    0.88408
# 6        0.153052    0.88756
# 7        0.150208    0.88924
# 8        0.145094    0.89224
# 9        0.141177    0.89480

# %% [markdown]
# ### Best Performance and number of parameters

# %% [markdown]
# You must report this number in you final report.

# %%
best_score = pd.DataFrame(all_results)['valid_acc'].max() * 100
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params}")
print('Best model preformance is: %%%.1f' % best_score)
# Out:
# Number of parameters: 60801536
# Best model preformance is: %89.5

# %% [markdown]
# ### Save PEFT file

# %% [markdown]
# We expect you to <font color='#FF7373'>upload this file </font> with the rest of your files.

# %%
peft_dict = {
    key: val
    for (key, val) in model.state_dict().items()
    if 'sharif_llm' in key
}
torch.save(peft_dict, 'lora.pt')

# %% [markdown]
# # Use external library

# %%
# !pip install peft
# Out:
# Requirement already satisfied: peft in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (0.6.1)
# Requirement already satisfied: numpy>=1.17 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from peft) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from peft) (23.1)
# Requirement already satisfied: psutil in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from peft) (6.0)
# Collecting torch>=1.13.0 (from peft)
#   Using cached torch-2.1.0-cp38-cp38-manylinux1_x86_64.whl (670.2 MB)
# Requirement already satisfied: transformers in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from peft) (4.35.0)
# Requirement already satisfied: tqdm in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from peft) (4.65.0)
# Collecting accelerate>=0.21.0 (from peft)
#   Using cached accelerate-0.24.1-py3-none-any.whl (261 kB)
# Requirement already satisfied: safetensors in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from peft) (0.3.1)
# Requirement already satisfied: huggingface-hub in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from accelerate>=0.21.0->peft) (0.17.3)
# Requirement already satisfied: filelock in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (3.12.2)
# Requirement already satisfied: typing-extensions in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (4.7.1)
# Requirement already satisfied: sympy in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (1.12)
# Requirement already satisfied: networkx in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (3.1)
# Requirement already satisfied: jinja2 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: fsspec in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from torch>=1.13.0->peft) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft) (12.3.52)
# Requirement already satisfied: regex!=2019.12.17 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from transformers->peft) (2023.6.3)
# Requirement already satisfied: requests in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from transformers->peft) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from transformers->peft) (0.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from requests->transformers->peft) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from requests->transformers->peft) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from requests->transformers->peft) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from requests->transformers->peft) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /home/oyarhose/miniconda/envs/py38/lib/python3.8/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Installing collected packages: torch, accelerate
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0
#     Uninstalling torch-1.10.0:
#       Successfully uninstalled torch-1.10.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.20.1
#     Uninstalling accelerate-0.20.1:
#       Successfully uninstalled accelerate-0.20.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 0.10.0+cu113 requires torch==1.10.0, but you have torch 2.1.0 which is incompatible.
# torchvision 0.11.1+cu113 requires torch==1.10.0, but you have torch 2.1.0 which is incompatible.
# Successfully installed accelerate-0.24.1 torch-2.1.0

# %% [markdown]
# Use `PEFT` library to do the same thing. [link](https://huggingface.co/docs/peft/install)
#
# For hyperparameters, test with `RANK=1` and `RANK=8` and report them in your report.

# %% [markdown]
# ## Rank = 1

# %%
model = T5ForConditionalGeneration.from_pretrained(BASE_MODEL_NAME)

######### Your code begins #########
from peft import LoraConfig, get_peft_model
RANK = 1
config = LoraConfig(
    r=RANK,
    lora_alpha=ALPHA,
    target_modules=["q", "v"],
    bias="none",
)
lora_model = get_peft_model(model, config)

# %%
model.to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
compute_metrics = accuracy_score
all_results = []
for epoch in range(EPOCHS):
    epoch_results = {'epoch': epoch}

    epoch_results.update(
        train_loop(
            model=model,
            loader=train_loader,
            optimizer=optimizer,
        )
    )

    epoch_results.update(
        valid_loop(
            model=model,
            loader=test_loader,
            compute_metrics=compute_metrics,
        )
    )
    all_results.append(epoch_results)

    display.clear_output()
    display.display(pd.DataFrame(all_results).set_index('epoch'))
# Out:
#        train_loss  valid_acc
# epoch
# 0        3.047142    0.81668
# 1        0.220083    0.84448
# 2        0.192919    0.85788
# 3        0.179042    0.86628
# 4        0.171370    0.87072
# 5        0.165266    0.87388
# 6        0.159560    0.88224
# 7        0.155448    0.88400
# 8        0.153958    0.88628
# 9        0.148985    0.88756

# %%
best_score = pd.DataFrame(all_results)['valid_acc'].max() * 100
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params}")
print('Best model preformance is: %%%.1f' % best_score)
# Out:
# Number of parameters: 60543488
# Best model preformance is: %88.8

# %% [markdown]
# ## Rank = 8

# %%
model = T5ForConditionalGeneration.from_pretrained(BASE_MODEL_NAME)

######### Your code begins #########
from peft import LoraConfig, get_peft_model
RANK = 8
config = LoraConfig(
    r=RANK,
    lora_alpha=ALPHA,
    target_modules=["q", "v"],
    bias="none",
)
lora_model = get_peft_model(model, config)

# %%
model.to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
compute_metrics = accuracy_score
all_results = []
for epoch in range(EPOCHS):
    epoch_results = {'epoch': epoch}

    epoch_results.update(
        train_loop(
            model=model,
            loader=train_loader,
            optimizer=optimizer,
        )
    )

    epoch_results.update(
        valid_loop(
            model=model,
            loader=test_loader,
            compute_metrics=compute_metrics,
        )
    )
    all_results.append(epoch_results)

    display.clear_output()
    display.display(pd.DataFrame(all_results).set_index('epoch'))
# Out:
#        train_loss  valid_acc
# epoch
# 0        3.083702    0.82008
# 1        0.219128    0.84640
# 2        0.191182    0.86060
# 3        0.178393    0.86780
# 4        0.170290    0.87344
# 5        0.164189    0.87800
# 6        0.160150    0.88108
# 7        0.155884    0.88540
# 8        0.152950    0.88644
# 9        0.148986    0.88900

# %%
best_score = pd.DataFrame(all_results)['valid_acc'].max() * 100
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params}")
print('Best model preformance is: %%%.1f' % best_score)
# Out:
# Number of parameters: 60801536
# Best model preformance is: %88.9
